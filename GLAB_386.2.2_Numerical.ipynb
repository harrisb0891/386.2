# %% [markdown]
# # GLAB 386.2.2 Numerical & Mathmatical Calculations

# %%
import numpy as np

# %%
python_list = [1, 2, 3, 4, 5]

numpy_1d = np.array(python_list)
print(numpy_1d_array)
# Out:
# [1 2 3 4 5]

# %%
# Attributes

# print the array

#print the shape of the array

#print the size of the array

print('array', numpy_1d)
print('shape', numpy_1d.shape)
print('size', numpy_1d.size)    
print('data type', numpy_1d.dtype)
# Out:
# array [1 2 3 4 5]
# shape (5,)
# size 5
# data type int64

# %%
arr1 = np.array([10, 20, 30, 40])
arr2 = np.array([2, 4, 6, 8])

# Element wise addition and save into new variable
arr3 = arr1 + arr2

# Element wise subtraction and save into new variable
arr4 = arr1 - arr2

# Element wise multiplication and save into new variable
arr5 = arr1 * arr2

# Element wise division and save into new variable
arr6 = arr1 / arr2


# Print out variables
print('Array 1:', arr1)
print('Array 2:', arr2)
print('-'*30)
print('Array 3 (Addition):', arr3)
print('Array 4 (Subtraction):', arr4)
print('Array 5 (Multiplication):', arr5)
print('Array 6 (Division):', arr6)
# Out:
# Array 1: [10 20 30 40]
# Array 2: [2 4 6 8]
# ------------------------------
# Array 3 (Addition): [12 24 36 48]
# Array 4 (Subtraction): [ 8 16 24 32]
# Array 5 (Multiplication): [ 20  80 180 320]
# Array 6 (Division): [5. 5. 5. 5.]

# %%
data = np.array([85, 90, 78, 92, 88, 95])

# Calculate the mean - save in variables
mean = np.mean(data)

# Calculate the median - save in variables
median = np.median(data)

# Calculate the standard deviation - save in variables
std_dev = np.std(data)


# Calculate the range - save in variables
range_data = np.max(data) - np.min(data)

# Calculate the variance - save in variables
variance = np.var(data)

#Print out your values
print('Mean:', mean)
print('Median:', median)
print('Standard Deviation:', std_dev)
print('Range:', range_data)
print('Variance:', variance)
# Out:
# Mean: 88.0
# Median: 89.0
# Standard Deviation: 5.446711546122731
# Range: 17
# Variance: 29.666666666666668
